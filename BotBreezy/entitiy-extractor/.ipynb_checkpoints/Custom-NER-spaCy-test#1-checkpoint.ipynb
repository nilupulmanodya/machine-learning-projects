# %% [markdown]
# 1. Load the dataset and Create an NLP Model

# %%
# import the required libraries
import spacy
import random

# %% [markdown]
#  create a model if there is no existing model otherwise load the existing model

# %%
# Initial parameters
model_file = None # set esisting model name other wise set it to None
iterations= 50 # Training data
TRAINING_DATA = [('what is the price of McVeggie?', {'entities': [(21, 29, 'FoodProduct')]}),
                 ('what is the price of McEgg?', {'entities': [(21, 26, 'FoodProduct')]}),
                 ('what is the price of McChicken?', {'entities': [(21, 30, 'FoodProduct')]}),
                 ('what is the price of McSpicy Paneer?', {'entities': [(21, 35, 'FoodProduct')]}),
                 ('what is the price of McSpicy Chicken?', {'entities': [(21, 36, 'FoodProduct')]})] 
# Testing sample data       
test_sample='what is the price of McAloo?'
# Create NLP model
if model_file is not None:
    " "
    nlp = spacy.load(model_file)  
    print("Load Existing NER Model ", model_file)
else:
    nlp = spacy.blank('en')  
    print("Created blank NLP model")
# Out:
# Created blank NLP model

# %% [markdown]
# Create an NLP Pipeline
# First check for exisitng pipelines, if not create new one

# %%
# Create NLP Pipeline
if 'ner' not in nlp.pipe_names:
    ner_pipe = 'ner'
    nlp.add_pipe(ner_pipe, last=True)
    ner_pipe = nlp.get_pipe('ner')
else:
    ner_pipe = nlp.get_pipe('ner')

# %% [markdown]
# Add Entities Labels
#
# add entities' labels to the pipeline. First, iterate the training dataset and then add each entity to the model

# %%
# Add entities labels to the ner pipeline
for text, annotations in TRAINING_DATA:
    for entity in annotations.get('entities'):
        ner_pipe.add_label(entity[2])

# %% [markdown]
# Train NER model
#
# First, disable all other pipelines and then go only NER training. In NER training, create an optimizer. after that, update nlp model based on text and annotations in the training dataset. This process continues to a defined number of iterations.

# %%
from spacy.training.example import Example

# %%
# get names of other pipes to disable them during training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']# train NER Model

with nlp.disable_pipes(*other_pipes):  # only train NER
    nlp.begin_training()
    for itn in range(iterations):
        print("Iteration Number:" + str(itn))
        random.shuffle(TRAINING_DATA)
        losses = {}
        for text, annotations in TRAINING_DATA:
            doc = nlp.make_doc(text)
            print(doc,annotations)
            example = Example.from_dict(doc, annotations)
            nlp.update([example],drop=0.2,sgd=optimizer,losses=losses)
        print("Loss:",losses)
# Out:
# Iteration Number:0
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# Loss: {'ner': 27.445197105407715}
# Iteration Number:1
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# Loss: {'ner': 14.661988038569689}
# Iteration Number:2
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# Loss: {'ner': 6.635495549962798}
# Iteration Number:3
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# Loss: {'ner': 6.958821613802485}
# Iteration Number:4
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# Loss: {'ner': 3.480241817311725}
# Iteration Number:5
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# Loss: {'ner': 1.8417870296063883}
# Iteration Number:6
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# Loss: {'ner': 1.6688225520042672}
# Iteration Number:7
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# Loss: {'ner': 2.839476986356829}
# Iteration Number:8
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# Loss: {'ner': 0.7213819630891344}
# Iteration Number:9
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# Loss: {'ner': 0.15684429907441746}
# Iteration Number:10
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# Loss: {'ner': 0.000316961134187554}
# Iteration Number:11
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# Loss: {'ner': 0.0010679862461100682}
# Iteration Number:12
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# Loss: {'ner': 2.0315963609159965e-05}
# Iteration Number:13
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# Loss: {'ner': 4.1118188606257614e-05}
# Iteration Number:14
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# Loss: {'ner': 3.125686545401094e-06}
# Iteration Number:15
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# Loss: {'ner': 4.3365255093744483e-07}
# Iteration Number:16
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# Loss: {'ner': 1.1073443438337277e-06}
# Iteration Number:17
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# Loss: {'ner': 3.856421196711092e-07}
# Iteration Number:18
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# Loss: {'ner': 1.428178079971231e-07}
# Iteration Number:19
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# Loss: {'ner': 4.429239125574989e-07}
# Iteration Number:20
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# Loss: {'ner': 2.021836875626671e-08}
# Iteration Number:21
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# Loss: {'ner': 9.495222592839442e-08}
# Iteration Number:22
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# Loss: {'ner': 2.4436310674779085e-07}
# Iteration Number:23
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# Loss: {'ner': 3.342870362431439e-07}
# Iteration Number:24
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# Loss: {'ner': 1.4535447240901405e-05}
# Iteration Number:25
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# Loss: {'ner': 3.0378486321444145e-08}
# Iteration Number:26
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# Loss: {'ner': 1.1627375455017159e-06}
# Iteration Number:27
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# Loss: {'ner': 5.410413337212031e-09}
# Iteration Number:28
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# Loss: {'ner': 6.490470414158842e-09}
# Iteration Number:29
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# Loss: {'ner': 3.056028350388764e-08}
# Iteration Number:30
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# Loss: {'ner': 1.0587220446056872e-08}
# Iteration Number:31
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# Loss: {'ner': 2.3418498601393682e-08}
# Iteration Number:32
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# Loss: {'ner': 5.8468055701081175e-08}
# Iteration Number:33
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# Loss: {'ner': 6.14072870845192e-08}
# Iteration Number:34
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# Loss: {'ner': 2.22318121347916e-07}
# Iteration Number:35
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# Loss: {'ner': 2.509712665309012e-07}
# Iteration Number:36
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# Loss: {'ner': 1.4959766941972728e-07}
# Iteration Number:37
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# Loss: {'ner': 1.5069146090379158e-08}
# Iteration Number:38
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# Loss: {'ner': 5.790097270178313e-09}
# Iteration Number:39
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# Loss: {'ner': 4.0672020555790874e-08}
# Iteration Number:40
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# Loss: {'ner': 6.071501396638602e-08}
# Iteration Number:41
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# Loss: {'ner': 2.3165595778457167e-08}
# Iteration Number:42
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# Loss: {'ner': 3.624039540601805e-08}
# Iteration Number:43
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# Loss: {'ner': 1.5011550153350555e-08}
# Iteration Number:44
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# Loss: {'ner': 5.495275326362795e-07}
# Iteration Number:45
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# Loss: {'ner': 8.616954395110208e-08}
# Iteration Number:46
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# Loss: {'ner': 1.8040435821941984e-07}
# Iteration Number:47
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# Loss: {'ner': 3.9372950350743686e-08}
# Iteration Number:48
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# Loss: {'ner': 2.905260226351379e-09}
# Iteration Number:49
# what is the price of McChicken? {'entities': [(21, 30, 'FoodProduct')]}
# what is the price of McEgg? {'entities': [(21, 26, 'FoodProduct')]}
# what is the price of McSpicy Chicken? {'entities': [(21, 36, 'FoodProduct')]}
# what is the price of McVeggie? {'entities': [(21, 29, 'FoodProduct')]}
# what is the price of McSpicy Paneer? {'entities': [(21, 35, 'FoodProduct')]}
# Loss: {'ner': 4.837002082591168e-09}

# %%
# save model
#nlp.to_disk(model_file)

# %%
# test model
test_document = nlp(test_sample)

for ent in test_document.ents:
    print(ent)
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# McAloo
# McAloo 21 27 FoodProduct
